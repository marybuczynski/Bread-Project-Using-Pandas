# %% [markdown]
# # CICS 397A Final Project
# ### Mary Buczynski and Sophia Fortier

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import metrics

# %matplotlib inline

# %%
# Read in CSV
bread_df = pd.read_csv("breads.csv")
bread_df
# Out:
#           id         description    fat  sodium  carbohydrates  fiber  sugars  \
# 0    1886332   WHOLE WHEAT BREAD  1.500   170.0           19.0  3.010     3.0
# 1    2078782   WHOLE WHEAT BREAD  2.000   230.0           25.0  3.020     5.0
# 2    2071180   WHOLE WHEAT BREAD  1.500   210.0           19.0  3.000     3.0
# 3    2286812   WHOLE WHEAT BREAD  1.000   170.0           19.0  3.010     3.0
# 4    1957492   WHOLE WHEAT BREAD  0.998   135.0           13.0  1.980     2.0
# ..       ...                 ...    ...     ...            ...    ...     ...
# 154  2095447     PRETZEL CHALLAH  2.500   130.0           25.0  0.990     4.0
# 155  1918250      RAISIN CHALLAH  3.500   250.0           32.0  2.000     6.0
# 156  2275196       ROUND CHALLAH  2.000    94.9           14.0  0.000     3.0
# 157  1922607      SQUARE CHALLAH  2.000   100.0           12.0  0.000     2.0
# 158  2094900  PLAIN BREAD (NAAN)  1.500   220.0           35.0  0.994     2.0
#
#      addedSugar  protein  calories
# 0           NaN      5.0     100.0
# 1           NaN      7.0     140.0
# 2           NaN      4.0     100.0
# 3           NaN      5.0     100.0
# 4         0.992      4.0      70.1
# ..          ...      ...       ...
# 154         NaN      4.0     140.0
# 155         NaN     10.0     200.0
# 156         NaN      2.0      80.1
# 157         NaN      2.0      80.1
# 158         NaN      5.0     180.0
#
# [159 rows x 10 columns]

# %%
# Cleaning up the data

bread_df = bread_df.drop("id", axis=1) # Removing id column
bread_df = bread_df.drop("addedSugar", axis=1) # Removing addedSugar since most values are NaN

def fillCols(col):
    if col.name in ('fat', 'sodium', 'carbohydrates', 'fiber', 'sugars', 'protein', 'calories'):
        col = col.fillna(col.mean())
    return col

bread_df = bread_df.apply(fillCols) # Filling in the null values with the column mean
bread_df
# Out:
#             description    fat  sodium  carbohydrates  fiber  sugars  protein  \
# 0     WHOLE WHEAT BREAD  1.500   170.0           19.0  3.010     3.0      5.0
# 1     WHOLE WHEAT BREAD  2.000   230.0           25.0  3.020     5.0      7.0
# 2     WHOLE WHEAT BREAD  1.500   210.0           19.0  3.000     3.0      4.0
# 3     WHOLE WHEAT BREAD  1.000   170.0           19.0  3.010     3.0      5.0
# 4     WHOLE WHEAT BREAD  0.998   135.0           13.0  1.980     2.0      4.0
# ..                  ...    ...     ...            ...    ...     ...      ...
# 154     PRETZEL CHALLAH  2.500   130.0           25.0  0.990     4.0      4.0
# 155      RAISIN CHALLAH  3.500   250.0           32.0  2.000     6.0     10.0
# 156       ROUND CHALLAH  2.000    94.9           14.0  0.000     3.0      2.0
# 157      SQUARE CHALLAH  2.000   100.0           12.0  0.000     2.0      2.0
# 158  PLAIN BREAD (NAAN)  1.500   220.0           35.0  0.994     2.0      5.0
#
#      calories
# 0       100.0
# 1       140.0
# 2       100.0
# 3       100.0
# 4        70.1
# ..        ...
# 154     140.0
# 155     200.0
# 156      80.1
# 157      80.1
# 158     180.0
#
# [159 rows x 8 columns]

# %% [markdown]
# ## Agglomerative Clustering

# %%
clust_columns = ["fat", "sodium", "sugars"] # clustering on nutrients that are unhealthy in high quantities

num_clusts = 8

linkage_type = "ward"

cluster_df = bread_df[clust_columns].dropna()

scaler = StandardScaler()
scaled_data = scaler.fit_transform(cluster_df)

clustering = AgglomerativeClustering(n_clusters=num_clusts, linkage=linkage_type).fit(scaled_data)

cluster_df["cluster"] = clustering.labels_
bread_df["cluster"] = cluster_df["cluster"]
bread_df
# Out:
#             description    fat  sodium  carbohydrates  fiber  sugars  protein  \
# 0     WHOLE WHEAT BREAD  1.500   170.0           19.0  3.010     3.0      5.0
# 1     WHOLE WHEAT BREAD  2.000   230.0           25.0  3.020     5.0      7.0
# 2     WHOLE WHEAT BREAD  1.500   210.0           19.0  3.000     3.0      4.0
# 3     WHOLE WHEAT BREAD  1.000   170.0           19.0  3.010     3.0      5.0
# 4     WHOLE WHEAT BREAD  0.998   135.0           13.0  1.980     2.0      4.0
# ..                  ...    ...     ...            ...    ...     ...      ...
# 154     PRETZEL CHALLAH  2.500   130.0           25.0  0.990     4.0      4.0
# 155      RAISIN CHALLAH  3.500   250.0           32.0  2.000     6.0     10.0
# 156       ROUND CHALLAH  2.000    94.9           14.0  0.000     3.0      2.0
# 157      SQUARE CHALLAH  2.000   100.0           12.0  0.000     2.0      2.0
# 158  PLAIN BREAD (NAAN)  1.500   220.0           35.0  0.994     2.0      5.0
#
#      calories  cluster
# 0       100.0        4
# 1       140.0        7
# 2       100.0        4
# 3       100.0        4
# 4        70.1        5
# ..        ...      ...
# 154     140.0        7
# 155     200.0        1
# 156      80.1        5
# 157      80.1        5
# 158     180.0        4
#
# [159 rows x 9 columns]

# %%
cluster_breads = {}
for index, row in bread_df.reset_index()[['index', 'description', 'cluster']].iterrows():
    clust = row["cluster"]
    cluster_breads.setdefault(clust, []).append(row)
    
for cluster, rows in cluster_breads.items(): # displaying clusters
    print("cluster {} ({})".format(int(cluster), len(rows)))
    rows_tuples = [ tuple(row) for row in rows ]
    for row in sorted(rows_tuples, key=lambda x: x[0]):
        print("\t", row)
    print("\n")
# Out:
# cluster 4 (37)
# 	 (0, 'WHOLE WHEAT BREAD', 4)
# 	 (2, 'WHOLE WHEAT BREAD', 4)
# 	 (3, 'WHOLE WHEAT BREAD', 4)
# 	 (7, 'WHOLE WHEAT BREAD', 4)
# 	 (8, 'WHOLE WHEAT BREAD', 4)
# 	 (9, 'WHOLE WHEAT BREAD', 4)
# 	 (10, 'WHOLE WHEAT BREAD', 4)
# 	 (27, 'SOURDOUGH BREAD, SOURDOUGH', 4)
# 	 (30, 'SOURDOUGH BREAD, SOURDOUGH', 4)
# 	 (31, 'WHITE BREAD', 4)
# 	 (33, 'WHITE BREAD', 4)
# 	 (34, 'WHITE BREAD', 4)
# 	 (35, 'WHITE BREAD', 4)
# 	 (38, 'WHITE BREAD', 4)
# 	 (40, 'WHITE BREAD', 4)
# 	 (42, 'WHITE BREAD', 4)
# 	 (45, 'WHITE BREAD', 4)
# 	 (49, 'WHITE BREAD', 4)
# 	 (51, 'MULTIGRAIN BREAD', 4)
# 	 (54, 'MULTIGRAIN BREAD', 4)
# 	 (55, 'MULTIGRAIN BREAD', 4)
# 	 (60, 'MULTIGRAIN BREAD', 4)
# 	 (64, 'MULTIGRAIN BREAD', 4)
# 	 (67, 'MULTIGRAIN BREAD', 4)
# 	 (68, 'MULTIGRAIN BREAD', 4)
# 	 (71, 'RYE BREAD', 4)
# 	 (84, 'CIABATTA', 4)
# 	 (122, 'BAGUETTE CRISPS', 4)
# 	 (130, 'BRIOCHE ROLLS, BRIOCHE', 4)
# 	 (135, 'BRIOCHE BAKERY BREAD, BRIOCHE', 4)
# 	 (136, 'BRIOCHE BAKERY BREAD, BRIOCHE', 4)
# 	 (137, 'BRIOCHE BAKERY BREAD, BRIOCHE', 4)
# 	 (138, 'BRIOCHE BAKERY BREAD, BRIOCHE', 4)
# 	 (142, 'CHALLAH', 4)
# 	 (146, 'CHALLAH ORGANIC BREAD, CHALLAH', 4)
# 	 (150, 'CHALLAH BREAD', 4)
# 	 (158, 'PLAIN BREAD (NAAN)', 4)
#
#
# cluster 7 (13)
# 	 (1, 'WHOLE WHEAT BREAD', 7)
# 	 (47, 'WHITE BREAD', 7)
# 	 (56, 'MULTIGRAIN BREAD', 7)
# 	 (61, 'MULTIGRAIN BREAD', 7)
# 	 (62, 'MULTIGRAIN BREAD', 7)
# 	 (66, 'MULTIGRAIN BREAD', 7)
# 	 (118, 'BAGUETTE CRISPS', 7)
# 	 (125, 'BRIOCHE', 7)
# 	 (128, 'BRIOCHE BREAD, BRIOCHE', 7)
# 	 (134, 'BRIOCHE SLICED, BRIOCHE', 7)
# 	 (147, 'BRAIDED CHALLAH BREAD, BRAIDED CHALLAH', 7)
# 	 (153, 'KOSHER CHALLAH', 7)
# 	 (154, 'PRETZEL CHALLAH', 7)
#
#
# cluster 5 (28)
# 	 (4, 'WHOLE WHEAT BREAD', 5)
# 	 (5, 'WHOLE WHEAT BREAD', 5)
# 	 (6, 'WHOLE WHEAT BREAD', 5)
# 	 (11, 'WHOLE WHEAT BREAD', 5)
# 	 (12, 'WHOLE WHEAT BREAD', 5)
# 	 (13, 'SOURDOUGH BREAD', 5)
# 	 (20, 'SOURDOUGH BREAD', 5)
# 	 (21, 'SOURDOUGH BREAD', 5)
# 	 (23, 'SOURDOUGH BREAD', 5)
# 	 (32, 'WHITE BREAD', 5)
# 	 (39, 'WHITE BREAD', 5)
# 	 (41, 'WHITE BREAD', 5)
# 	 (46, 'WHITE BREAD', 5)
# 	 (48, 'WHITE BREAD', 5)
# 	 (50, 'WHITE BREAD', 5)
# 	 (57, 'MULTIGRAIN BREAD', 5)
# 	 (58, 'MULTIGRAIN BREAD', 5)
# 	 (59, 'MULTIGRAIN BREAD', 5)
# 	 (65, 'MULTIGRAIN BREAD', 5)
# 	 (70, 'MULTIGRAIN BREAD', 5)
# 	 (83, 'PUMPERNICKEL RYE BREAD, PUMPERNICKEL', 5)
# 	 (126, 'BRIOCHE', 5)
# 	 (133, 'BRIOCHE ROLLS, BRIOCHE', 5)
# 	 (148, '\\ROUND CHALLAH', 5)
# 	 (149, 'BRAIDED CHALLAH', 5)
# 	 (151, 'CHALLAH BREAD', 5)
# 	 (156, 'ROUND CHALLAH', 5)
# 	 (157, 'SQUARE CHALLAH', 5)
#
#
# cluster 6 (22)
# 	 (14, 'SOURDOUGH BREAD', 6)
# 	 (15, 'SOURDOUGH BREAD', 6)
# 	 (17, 'SOURDOUGH BREAD', 6)
# 	 (18, 'SOURDOUGH BREAD', 6)
# 	 (19, 'SOURDOUGH BREAD', 6)
# 	 (26, 'SOURDOUGH BREAD, SOURDOUGH', 6)
# 	 (28, 'SOURDOUGH BREAD, SOURDOUGH', 6)
# 	 (29, 'SOURDOUGH BREAD, SOURDOUGH', 6)
# 	 (37, 'WHITE BREAD', 6)
# 	 (44, 'WHITE BREAD', 6)
# 	 (52, 'MULTIGRAIN BREAD', 6)
# 	 (63, 'MULTIGRAIN BREAD', 6)
# 	 (73, 'RYE BREAD', 6)
# 	 (77, 'NO SEEDS PUMPERNICKEL BREAD, PUMPERNICKEL', 6)
# 	 (80, 'PUMPERNICKEL PREMIUM BREAD, PUMPERNICKEL', 6)
# 	 (81, 'PUMPERNICKEL RYE BREAD, PUMPERNICKEL', 6)
# 	 (82, 'PUMPERNICKEL RYE BREAD, PUMPERNICKEL', 6)
# 	 (89, 'CIABATTA BATON, CIABATTA', 6)
# 	 (97, 'CIABATTA LOAF, CIABATTA', 6)
# 	 (112, 'DEMI BAGUETTE ARTISAN, DEMI BAGUETTE', 6)
# 	 (114, 'ARTISAN BAGUETTE', 6)
# 	 (116, 'ARTISAN BAGUETTE', 6)
#
#
# cluster 0 (14)
# 	 (16, 'SOURDOUGH BREAD', 0)
# 	 (36, 'WHITE BREAD', 0)
# 	 (43, 'WHITE BREAD', 0)
# 	 (53, 'MULTIGRAIN BREAD', 0)
# 	 (69, 'MULTIGRAIN BREAD', 0)
# 	 (86, 'CIABATTA', 0)
# 	 (93, 'CIABATTA LOAF, CIABATTA', 0)
# 	 (94, 'CIABATTA LOAF, CIABATTA', 0)
# 	 (100, 'CIABATTA ROLLS, CIABATTA', 0)
# 	 (117, 'ARTISANAL BAGUETTES', 0)
# 	 (119, 'BAGUETTE CRISPS', 0)
# 	 (120, 'BAGUETTE CRISPS', 0)
# 	 (121, 'BAGUETTE CRISPS', 0)
# 	 (152, 'CHALLAH ROLLS', 0)
#
#
# cluster 2 (27)
# 	 (22, 'SOURDOUGH BREAD', 2)
# 	 (24, 'SOURDOUGH BREAD', 2)
# 	 (72, 'RYE BREAD', 2)
# 	 (74, 'PUMPERNICKEL', 2)
# 	 (75, 'PUMPERNICKEL BAGELS, PUMPERNICKEL', 2)
# 	 (76, 'PUMPERNICKEL BOULE, PUMPERNICKEL', 2)
# 	 (78, 'PUMPERNICKEL ARTISAN BREAD, PUMPERNICKEL', 2)
# 	 (79, 'PUMPERNICKEL FLAVORED PRETZELS, PUMPERNICKEL', 2)
# 	 (85, 'CIABATTA', 2)
# 	 (87, 'CIABATTA', 2)
# 	 (88, 'CIABATTA BAGUETTE, CIABATTA', 2)
# 	 (90, 'CIABATTA BREAD, CIABATTA', 2)
# 	 (92, 'CIABATTA LOAF, CIABATTA', 2)
# 	 (95, 'CIABATTA LOAF, CIABATTA', 2)
# 	 (96, 'CIABATTA LOAF, CIABATTA', 2)
# 	 (98, 'CIABATTA LUNGA, CIABATTA', 2)
# 	 (99, 'CIABATTA ROLLS, CIABATTA', 2)
# 	 (101, 'CIABATTA ROLLS, CIABATTA', 2)
# 	 (103, 'BAGUETTE', 2)
# 	 (104, 'BAGUETTE', 2)
# 	 (106, 'BAGUETTE', 2)
# 	 (107, 'BAGUETTE', 2)
# 	 (108, 'BAGUETTE BREAD, BAGUETTE', 2)
# 	 (109, 'BAGUETTE BREAD, BAGUETTE', 2)
# 	 (110, 'WHITE BAGUETTE BREAD, BAGUETTE', 2)
# 	 (113, 'DEMI BAGUETTE BREAD, DEMI BAGUETTE', 2)
# 	 (115, 'ARTISAN BAGUETTE', 2)
#
#
# cluster 3 (5)
# 	 (25, 'SOURDOUGH BREAD', 3)
# 	 (91, 'CIABATTA BUNS, CIABATTA', 3)
# 	 (102, '6"" CIABATTA ROLLS, CIABATTA', 3)
# 	 (105, 'BAGUETTE', 3)
# 	 (111, 'BAGUETTE GLUTEN FREE BREADS, BAGUETTE', 3)
#
#
# cluster 1 (13)
# 	 (123, 'BRIOCHE', 1)
# 	 (124, 'BRIOCHE', 1)
# 	 (127, 'BRIOCHE BAGUETTES, BRIOCHE', 1)
# 	 (129, 'BRIOCHE BUNS, BRIOCHE', 1)
# 	 (131, 'BRIOCHE ROLLS, BRIOCHE', 1)
# 	 (132, 'BRIOCHE ROLLS, BRIOCHE', 1)
# 	 (139, 'BRIOCHE BURGER BUNS, BRIOCHE', 1)
# 	 (140, 'BRIOCHE BURGER BUNS, BRIOCHE', 1)
# 	 (141, 'BRIOCHE BURGER BUNS, BRIOCHE', 1)
# 	 (143, 'CHALLAH BUN, CHALLAH', 1)
# 	 (144, 'CHALLAH LOAF, CHALLAH', 1)
# 	 (145, 'CHALLAH CROWN LOAF, CHALLAH', 1)
# 	 (155, 'RAISIN CHALLAH', 1)

# %%
bread_df = bread_df.drop(columns="cluster", axis = 1) # removing cluster column for next steps

# %% [markdown]
# ## Supervised Learning

# %%
# Adding healthier vs. unhealthier class labels
def add_label(s):
    artisan = ["SOURDOUGH", "WHOLE WHEAT", "MULTIGRAIN", "RYE", "PUMPERNICKEL"]
    label = "Not Healthy"
    for bread_type in artisan:
        if bread_type in s:
            label = "Healthy"
    return label

bread_df['category'] = bread_df['description'].map(add_label)
bread_df
# Out:
#             description    fat  sodium  carbohydrates  fiber  sugars  protein  \
# 0     WHOLE WHEAT BREAD  1.500   170.0           19.0  3.010     3.0      5.0
# 1     WHOLE WHEAT BREAD  2.000   230.0           25.0  3.020     5.0      7.0
# 2     WHOLE WHEAT BREAD  1.500   210.0           19.0  3.000     3.0      4.0
# 3     WHOLE WHEAT BREAD  1.000   170.0           19.0  3.010     3.0      5.0
# 4     WHOLE WHEAT BREAD  0.998   135.0           13.0  1.980     2.0      4.0
# ..                  ...    ...     ...            ...    ...     ...      ...
# 154     PRETZEL CHALLAH  2.500   130.0           25.0  0.990     4.0      4.0
# 155      RAISIN CHALLAH  3.500   250.0           32.0  2.000     6.0     10.0
# 156       ROUND CHALLAH  2.000    94.9           14.0  0.000     3.0      2.0
# 157      SQUARE CHALLAH  2.000   100.0           12.0  0.000     2.0      2.0
# 158  PLAIN BREAD (NAAN)  1.500   220.0           35.0  0.994     2.0      5.0
#
#      calories     category
# 0       100.0      Healthy
# 1       140.0      Healthy
# 2       100.0      Healthy
# 3       100.0      Healthy
# 4        70.1      Healthy
# ..        ...          ...
# 154     140.0  Not Healthy
# 155     200.0  Not Healthy
# 156      80.1  Not Healthy
# 157      80.1  Not Healthy
# 158     180.0  Not Healthy
#
# [159 rows x 9 columns]

# %%
y = bread_df["category"]
x = bread_df.drop(["category", "description"], axis = 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
clf = DecisionTreeClassifier()

clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

acc = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", acc)

recall = metrics.recall_score(y_test, y_pred, average='macro')
print("Recall:", recall)

precision = metrics.precision_score(y_test, y_pred, average='weighted')
print("Precision:", precision)
# Out:
# Accuracy: 0.71875
# Recall: 0.7023809523809523
# Precision: 0.7199675324675325

# %% [markdown]
# ## Visualization

# %%
# Heat Map

sns.heatmap(bread_df[["fat", "sodium", "sugars", "carbohydrates", "calories", "protein", "fiber"]].corr(), cmap="PuBu")
# Out:
# <AxesSubplot:>

# %%
# Facetted Boxplots

fig, axs = plt.subplots(3, 2, figsize=(7, 8))

sns.boxplot(data=bread_df, x='category', y="fiber", color="skyblue", ax=axs[0, 0])
sns.boxplot(data=bread_df, x='category', y="sodium", color="olive", ax=axs[0, 1])
sns.boxplot(data=bread_df, x='category', y="carbohydrates", color="gold", ax=axs[1, 0])
sns.boxplot(data=bread_df, x='category', y="calories", color="teal", ax=axs[1, 1])
sns.boxplot(data=bread_df, x='category', y="protein", color="cadetblue", ax=axs[2, 0])
sns.boxplot(data=bread_df, x='category', y="sugars", color="darkorange", ax=axs[2, 1])

fig.tight_layout()

# %%
# Decision Tree Diagram

list_nutrients = ['fat', 'sodium', 'carbohydrates', 'fiber', 'sugars', 'protein', 'calories']
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, feature_names = list_nutrients, filled=True)
